# %% [markdown]
# ## Python Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method to plot a graph
plt.plot(x, y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Title')
plt.show()

# %%
# subplots
plt.subplot(1, 2, 1) # row,column, subplot number
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2) # row, columnm, subplot number
plt.plot(y, x, 'g')

# %%
# Object oriented method
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.9, 0.9]) # left, botton, width, height
axes.plot(x, y)
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Object oriented method
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.9]) # left, botton, width, height
axes2 = fig.add_axes([0.7, 0.15, 0.2, 0.2]) # left, botton, width, height
axes1.plot(x, y)
axes1.set_xlabel('X Axis')
axes1.set_ylabel('Y Axis')
axes1.set_title('Title')
axes2.plot(y, x)
axes2.set_xlabel('X Axis')
axes2.set_ylabel('Y Axis')
axes2.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Subplots and axes

fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[0].set_title('First Plot')

axes[1].plot(y, x)
axes[1].set_title('Second Plot')
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %% [markdown]
# ### Figure Size and DPI

# %%
fig = plt.figure(figsize=(8, 2), dpi=100) # in figsize you pass a tuple to specify height and width; dpi is dots per pixel

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, y)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 4)) # in figsize you pass a tuple to specify height and width; dpi is dots per pixel

axes[0].plot(x, y)

axes[1].plot(y, x)

plt.tight_layout()

# %%
fig.savefig('example_image.pdf')

# %%
# Legends

fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes([0.1, 0.1, 0.9, 0.9])
ax.plot(x, x**2, label='x squared')
ax.plot(x, x**3, label='x cubed')

ax.legend(loc=0)

# %% [markdown]
# ### Plot appearance

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, x**2, label='x squared', color='green', linewidth=5, alpha=0.5, linestyle='-.' ) # alpha -> transparency
ax.plot(x, x**3, label='x cubed', color='red', linewidth=3, marker='*', markersize=20,
       markerfacecolor='blue')

ax.legend(loc=0)

ax.set_xlim([0, 4]) # set minium and maximum on x axis
ax.set_ylim([0, 65]) # set minium and maximum on y axis
# Out:
# (0, 65)
